# %%
import pandas as pd
import numpy as np

# %%
from io import StringIO

data = """Hours_Studied,Attendance,Gender,Parent_Education,Exam_Score
8.93,63,Female,Highschool,88.83
6.23,86,, ,44.34
8.94,63,, ,41.55
7.23,91,,Bachelors,38.74
7.53,69,Other,Masters,80.55
5.51,70,Other,Bachelors,32.13
9.6,87,Female,Highschool,82.29
6.8,67,Other,Highschool,36.48
4.81,99,, ,45.22
6.46,81,Other,Highschool,82.45
1.17,93,Male,,81.22
3.71,94,,Highschool,33.19
6.94,94,,Highschool,44.64
3.61,84,Female,Bachelors,50.08
6.56,93,Female,Highschool,77.41
4.86,65,Female,Masters,34.41
2.22,96,Other,Masters,68.9
3.68,60,Female,Masters,30.65
6.13,71,Female,Highschool,88.31
6.32,94,Female,Highschool,98.9
6.17,65,Other,Masters,79.24
6.88,76,Male,Highschool,42.71
6.87,68,,Masters,65.87
4.88,61,Female,,70.63
9.07,77,Male,Masters,85.13
4.31,95,, ,72.45
4.92,87,Female,,45.29
9.03,96,Female,Highschool,61.86
8.26,85,Other,Bachelors,91.52
7.33,63,Male,Bachelors,64.46
1.9,99,Other,Bachelors,80.09
9.28,95,,Highschool,64.03
7.43,90,Male,Highschool,79.6
9.99,89,Other,,64.87
2.35,93,Male,,89.12
8.81,78,Other,Bachelors,43.6
2.46,77,Male,,84.13
6.54,89,Male,Highschool,98.2
2.11,80,, ,90.36
8.63,62,,Highschool,84.63
8.27,65,,Bachelors,98.95
6.12,97,Male,Masters,82.75
4.66,72,Male,Masters,30.28
1.62,62,,Highschool,48.86
7.28,87,Female,Masters,58.73
,, ,Bachelors,
,,Other,,
,, ,,
,,Male,,
,, ,Bachelors,
"""
df = pd.read_csv(StringIO(data))
df.head()
# Out:
#    Hours_Studied  Attendance  Gender Parent_Education  Exam_Score
# 0           8.93        63.0  Female       Highschool       88.83
# 1           6.23        86.0     NaN                        44.34
# 2           8.94        63.0     NaN                        41.55
# 3           7.23        91.0     NaN        Bachelors       38.74
# 4           7.53        69.0   Other          Masters       80.55

# %%
df.isnull().sum()
# Out:
# Hours_Studied        5
# Attendance           5
# Gender              13
# Parent_Education     9
# Exam_Score           5
# dtype: int64

# %%
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df = df.dropna(how='all')
df["Gender"] = df["Gender"].fillna("Unknown")
df["Parent_Education"] = df["Parent_Education"].fillna("Unknown")
df["Hours_Studied"] = df["Hours_Studied"].fillna(df["Hours_Studied"].mean())
df["Attendance"] = df["Attendance"].fillna(df["Attendance"].mean())
df["Exam_Score"] = df["Exam_Score"].fillna(df["Exam_Score"].mean())
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Hours_Studied     50 non-null     float64
#  1   Attendance        50 non-null     float64
#  2   Gender            50 non-null     object
#  3   Parent_Education  50 non-null     object
#  4   Exam_Score        50 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 2.1+ KB
# /tmp/ipython-input-3970932652.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#    Hours_Studied  Attendance   Gender Parent_Education  Exam_Score
# 0           8.93        63.0   Female       Highschool       88.83
# 1           6.23        86.0  Unknown                        44.34
# 2           8.94        63.0  Unknown                        41.55
# ...

# %%
df.to_csv("students_data_cleaned.csv", index=False)
